# %% [markdown]
# # 在 Windows 設定中尋找 "排程" 選擇 "排程工作"
#
# ![crontab.PNG](attachment:crontab.PNG)
#
# ![crontab2.PNG](attachment:crontab2.PNG)
#
# ![crontab3.PNG](attachment:crontab3.PNG)
#
# ![crontab4.PNG](attachment:crontab4.PNG)
#
# ![crontab5.PNG](attachment:crontab5.PNG)
#
# ![crontab6.PNG](attachment:crontab6.PNG)
#
# ![crontab7.PNG](attachment:crontab7.PNG)
#
# ![crontab8.PNG](attachment:crontab8.PNG)

# %% [markdown]
# # 在任意路徑中放入一個 python 檔案
#
# 這個檔案將會建立一個檔案在桌面上，以便觀察。

# %%
import time
s = time.strftime("%Y%m%d%H%M%S", time.localtime())
with open("C:\\Users\\jiangsir\\Desktop\\crontab_"+s+".txt", "w+") as f:
    f.write("Hello world!!!!")
