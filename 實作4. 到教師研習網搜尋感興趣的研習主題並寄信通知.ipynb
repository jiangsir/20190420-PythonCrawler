# %% [markdown]
# # 到 "教師研習網查詢有興趣的研習"
#
# 由於教師研習網並沒有提供過濾有興趣的研習的通知，每次都通知一大堆不會參加的研習，到最後就不想看了。
#
# 我們利用瀏覽器爬蟲來完成這個任務吧。讓自己更輕鬆地獲知研習訊息。

# %% [markdown]
# # 單一條件查詢

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import requests
import pandas as pd

driver = webdriver.Chrome(executable_path="C:\\Users\\jiangsir\\Anaconda3\\chromedriver.exe")
driver.implicitly_wait(30)
verificationErrors = []
accept_next_alert = True

driver.get("https://www4.inservice.edu.tw/NAPP/OpenQuery.aspx")
driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").click()
driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").clear()
driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").send_keys("人工智慧")
driver.find_element_by_xpath("(.//*[normalize-space(text()) and normalize-space(.)='顯示更多方式'])[1]/following::span[1]").click()
element = driver.find_element_by_xpath('//*[@id="ctl00_CPH_Content_RG_SearchResult_ctl00"]')
html = element.get_attribute('outerHTML')
df = pd.read_html(html)
driver.close()
df[0]
# Out:
# 1
#                                    課程代碼                                研習名稱  \
# 0                               2604456            AI人工智慧物聯網音箱手作基礎課程研習(台南區)
# 1                               2611218  108年春季分享大師視野講座：我的醫生是機器人─人工智慧Watson
# 2                               2587435      縣級「新興科技」教師增能工作坊-AI人工智慧大數據(場次二)
# 3                               2615610               AI人工智慧語音控制與智慧小車(生活科技)
# 4                               2561041                           人工智慧教育的改變
# 5  1  每頁筆數：  select  5 items in 1 pages                                 NaN
#
#          開始日期        結束日期          辦理研習單位  \
# 0  2019/04/23  2019/04/23     臺南市  國立臺南二中
# 1  2019/04/26  2019/04/26  臺中市  國立自然科學博物館
# 2  2019/04/27  2019/06/15     彰化縣  縣立花壇國中
# 3  2019/04/30  2019/04/30     臺中市  私立明道高中
# 4  2019/05/22  2019/05/22     臺中市  市立仁美國小
# 5         NaN         NaN             NaN
#
#                                                   列表
# 0  26044562019/04/23~ 2019/04/23  AI人工智慧物聯網音箱手作基礎...
# 1  26112182019/04/26~ 2019/04/26  108年春季分享大師視野講座：...
# 2  25874352019/04/27~ 2019/06/15  縣級「新興科技」教師增能工作坊...
# 3  26156102019/04/30~ 2019/04/30  AI人工智慧語音控制與智慧小車...
# 4  25610412019/05/22~ 2019/05/22  人工智慧教育的改變  臺中市｜...
# 5                                                NaN

# %% [markdown]
# # 多條件查詢

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import requests
import pandas as pd
import smtplib
from email.mime.text import MIMEText

def query(driver, keyword):
    driver.get("https://www4.inservice.edu.tw/NAPP/OpenQuery.aspx")
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").click()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").clear()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").send_keys(keyword)
    #     driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").clear()
    #     driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").send_keys("人工智慧")
    driver.find_element_by_xpath("(.//*[normalize-space(text()) and normalize-space(.)='顯示更多方式'])[1]/following::span[1]").click()
    #elements = driver.find_elements_by_id('ctl00_CPH_Content_RG_SearchResult_ctl00')
    element = driver.find_element_by_xpath('//*[@id="ctl00_CPH_Content_RG_SearchResult_ctl00"]')
    #print(element.get_attribute('innerHTML'))
    #df = pd.read_html(element.get_attribute('innerHTML'))
    html = element.get_attribute('outerHTML')
    #print(html)
    return pd.read_html(html)



driver = webdriver.Chrome(executable_path="C:\\Users\\jiangsir\\Anaconda3\\chromedriver.exe")

driver.implicitly_wait(30)
verificationErrors = []
accept_next_alert = True

keywords = ["人工智慧", "物聯網"]

df = pd.DataFrame()
for keyword in keywords:
    df1 = query(driver, keyword)
    if df.empty:
        df = df1[0]
    else:
        df = pd.concat([df, df1[0]])

#driver.close()
driver.quit()

df
# Out:
#                                        課程代碼  \
# 0                                   2604456
# 1                                   2611218
# 2                                   2587435
# 3                                   2615610
# 4                                   2561041
# 5      1  每頁筆數：  select  5 items in 1 pages
# 0                                   2583168
# 1                                   2612897
# 2                                   2618972
# 3                                   2591997
# 4                                   2612898
# 5                                   2604456
# 6                                   2604255
# 7                                   2604501
# 8                                   2608404
# 9                                   2612899
# 10  123  每頁筆數：  select  25 items in 3 pages
#
#                                                  研習名稱        開始日期        結束日期  \
# 0                            AI人工智慧物聯網音箱手作基礎課程研習(台南區)  2019/04/23  2019/04/23
# 1                  108年春季分享大師視野講座：我的醫生是機器人─人工智慧Watson  2019/04/26  2019/04/26
# 2                      縣級「新興科技」教師增能工作坊-AI人工智慧大數據(場次二)  2019/04/27  2019/06/15
# 3                               AI人工智慧語音控制與智慧小車(生活科技)  2019/04/30  2019/04/30
# 4                                           人工智慧教育的改變  2019/05/22  2019/05/22
# 5                                                 NaN         NaN         NaN
# 0            [教專評鑑]用 Webduino 體驗 IoT 物聯網、3D設計跟你想的不一樣！  2019/04/19  2019/04/19
# 1                                  第二梯次：智慧物聯網的認識與應用研習  2019/04/19  2019/04/19
# 2                                        IOT雲端物聯網整合應用  2019/04/19  2019/04/19
# 3   107學年度第二學期高中職優質化107-3(A3)深化教師教學專業計畫-樹莓派物聯網應用控制...  2019/04/20  2019/04/20
# 4                                  第三梯次：智慧物聯網的認識與應用研習  2019/04/22  2019/04/22
# 5                            AI人工智慧物聯網音箱手作基礎課程研習(台南區)  2019/04/23  2019/04/23
# 6                  新北市自造教育及科技中心教師培訓研習－－新興科技 /物聯網介紹與應用  2019/04/24  2019/04/24
# 7                       IoT物聯網資訊應用-Webduino教學實務工作坊(二)  2019/04/26  2019/04/26
# 8                       NKNUScratch3.0＋電動車+物聯網衛星基地認證班  2019/04/27  2019/04/27
# 9                                  第四梯次：智慧物聯網的認識與應用研習  2019/04/29  2019/04/29
# 10                                                NaN         NaN         NaN
#
#             辦理研習單位                                                 列表
# 0      臺南市  國立臺南二中  26044562019/04/23~ 2019/04/23  AI人工智慧物聯網音箱手作基礎...
# 1   臺中市  國立自然科學博物館  26112182019/04/26~ 2019/04/26  108年春季分享大師視野講座：...
# 2      彰化縣  縣立花壇國中  25874352019/04/27~ 2019/06/15  縣級「新興科技」教師增能工作坊...
# 3      臺中市  私立明道高中  26156102019/04/30~ 2019/04/30  AI人工智慧語音控制與智慧小車...
# 4      臺中市  市立仁美國小  25610412019/05/22~ 2019/05/22  人工智慧教育的改變  臺中市｜...
# 5              NaN                                                NaN
# 0      高雄市  國立鳳山商工  25831682019/04/19~ 2019/04/19  [教專評鑑]用 Webduin...
# 1      南投縣  縣立康壽國小  26128972019/04/19~ 2019/04/19  第二梯次：智慧物聯網的認識與應...
# 2      新竹市  私立磐石高中  26189722019/04/19~ 2019/04/19  IOT雲端物聯網整合應用  新...
# 3      臺中市  市立霧峰農工  25919972019/04/20~ 2019/04/20  107學年度第二學期高中職優質...
# 4      南投縣  縣立康壽國小  26128982019/04/22~ 2019/04/22  第三梯次：智慧物聯網的認識與應...
# 5      臺南市  國立臺南二中  26044562019/04/23~ 2019/04/23  AI人工智慧物聯網音箱手作基礎...
# 6      新北市  市立積穗國小  26042552019/04/24~ 2019/04/24  新北市自造教育及科技中心教師培...
# 7      新竹縣  縣立東興國小  26045012019/04/26~ 2019/04/26  IoT物聯網資訊應用-Webd...
# 8    高雄市  國立高雄師範大學  26084042019/04/27~ 2019/04/27  NKNUScratch3.0＋...
# 9      南投縣  縣立康壽國小  26128992019/04/29~ 2019/04/29  第四梯次：智慧物聯網的認識與應...
# 10             NaN                                                NaN

# %% [markdown]
# # 把査到的資訊寄信給自己
#
# 以下為 mailer.py 程式，可放入排程，讓 windows 定時執行。

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import requests
import pandas as pd
import smtplib
from email.mime.text import MIMEText




def mailer(subject, html, mailto='jiangzero@gmail.com', mailfrom='jiangsir@tea.nknush.kh.edu.tw', passwd='igajmuqzhnhuyzil'):
    mime=MIMEText(html, "html", "utf-8")
    mime["Subject"]=subject
    mime["From"]="教師研習自動通知"
    mime["To"]=""
    msg=mime.as_string()

    smtpssl=smtplib.SMTP_SSL("smtp.gmail.com", 465) 
    smtpssl.ehlo()
    smtpssl.login(mailfrom, passwd)

    to_addr=[mailto]
    status=smtpssl.sendmail(mailfrom, to_addr, msg)
    if status=={}:
        print("郵件傳送成功!")
    else:
        print("郵件傳送失敗!")
    smtpssl.quit()    

def query(driver, keyword):
    driver.get("https://www4.inservice.edu.tw/NAPP/OpenQuery.aspx")
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").click()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").clear()
    driver.find_element_by_id("ctl00_CPH_Content_RTB_CourseName").send_keys(keyword)
    driver.find_element_by_xpath("(.//*[normalize-space(text()) and normalize-space(.)='顯示更多方式'])[1]/following::span[1]").click()
    element = driver.find_element_by_xpath('//*[@id="ctl00_CPH_Content_RG_SearchResult_ctl00"]')
    html = element.get_attribute('outerHTML')
    return pd.read_html(html)

driver = webdriver.Chrome(executable_path="C:\\Users\\jiangsir\\Anaconda3\\chromedriver.exe")
driver.implicitly_wait(30)
verificationErrors = []
accept_next_alert = True

keywords = ["人工智慧", "物聯網"]

df = pd.DataFrame()
for keyword in keywords:
    df1 = query(driver, keyword)
    if df.empty:
        df = df1[0]
    else:
        df = pd.concat([df, df1[0]])

#driver.close()
driver.quit()

mailer("教師研習網篩選通知("+str(keywords)+")", df.to_html())
# Out:
# 郵件傳送成功!
